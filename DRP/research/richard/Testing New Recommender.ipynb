# %%
from DRP.recommender.ReactionRecommender import Recommender
from DRP.recommender.SampleGridParameters import GridValueGenerator
from DRP.models import ModelContainer
from DRP.models import CompoundQuantity, BoolRxnDescriptor

# %%
rec = Recommender(ModelContainer.objects.get(pk=1), GridValueGenerator().main(),{BoolRxnDescriptor.objects.get(pk=2):[True]})
# Out:
# {<NumericDescriptor: Reaction temperature in degrees C>: [363.15, 423.15], <NumericDescriptor: Reaction time in minutes>: [1440, 3600], <NumericDescriptor: Reaction pH>: [1, 2, 3, 8]}

# %%
recommendations = rec.recommend()
# Out:
# [[<Compound: Compound object>, <Compound: Compound object>, <Compound: Compound object>], [<Compound: Compound object>, <Compound: Compound object>, <Compound: Compound object>], [<Compound: Compound object>, <Compound: Compound object>, <Compound: Compound object>], [<Compound: Compound object>, <Compound: Compound object>, <Compound: Compound object>]]
# step1
# step2
# /home/rich/DRP/DRP/plugins/rxndescriptors/drp.py:714: UserWarning: Could not find descriptor value for descriptor Inorg_asa_polar_pH1_0_ChemAxon_cxcalc_15_6_gmean_count and reaction Reaction_133226
#   reaction_pH_descriptor_heading, reaction))
#
# /home/rich/DRP/DRP/plugins/rxndescriptors/drp.py:711: UserWarning: Could not find descriptor value for a pH or Ox role descriptor.
#   'Could not find descriptor value for a pH or Ox role descriptor.')
#
# /home/rich/DRP/DRP/plugins/rxndescriptors/drp.py:714: UserWarning: Could not find descriptor value for descriptor Org_polar_surface_area_pH1_0_ChemAxon_cxcalc_16_5_gmean_molarity and reaction Reaction_133226
#   reaction_pH_descriptor_heading, reaction))
#
# /home/rich/DRP/DRP/plugins/rxndescriptors/drp.py:714: UserWarning: Could not find descriptor value for descriptor Org_polar_surface_area_pH1_0_ChemAxon_cxcalc_16_5_Max and reaction Reaction_133226
#   reaction_pH_descriptor_heading, reaction))
#
# /home/rich/DRP/DRP/plugins/rxndescriptors/drp.py:714: UserWarning: Could not find descriptor value for descriptor Inorg_molpol_pH1_0_ChemAxon_cxcalc_15_6_gmean_count and reaction Reaction_133226
#   reaction_pH_descriptor_heading, reaction))
#
# /home/rich/DRP/DRP/plugins/rxndescriptors/drp.py:714: UserWarning: Could not find descriptor value for descriptor Solv_polar_surface_area_pH1_0_ChemAxon_cxcalc_16_5_Max and reaction Reaction_133226
#   reaction_pH_descriptor_heading, reaction))
#
# /home/rich/DRP/DRP/plugins/rxndescriptors/drp.py:714: UserWarning: Could not find descriptor value for descriptor Org_avgpol_pH1_0_ChemAxon_cxcalc_15_6_Max and reaction Reaction_133226
#   reaction_pH_descriptor_heading, reaction))
#
# /home/rich/DRP/DRP/plugins/rxndescriptors/drp.py:714: UserWarning: Could not find descriptor value for descriptor Org_asa+_pH1_0_ChemAxon_cxcalc_15_6_gmean_count and reaction Reaction_133226
#   reaction_pH_descriptor_heading, reaction))
#
# /home/rich/DRP/DRP/plugins/rxndescriptors/drp.py:714: UserWarning: Could not find descriptor value for descriptor Solv_hbda_don_pH1_0_ChemAxon_cxcalc_15_6_gmean_count and reaction Reaction_133226
#   reaction_pH_descriptor_heading, reaction))
#
# /home/rich/DRP/DRP/plugins/rxndescriptors/drp.py:714: UserWarning: Could not find descriptor value for descriptor Org_hbda_don_pH1_0_ChemAxon_cxcalc_15_6_gmean_count and reaction Reaction_133226
#   reaction_pH_descriptor_heading, reaction))
#
# /home/rich/DRP/DRP/plugins/rxndescriptors/drp.py:714: UserWarning: Could not find descriptor value for descriptor Org_asa_hydrophobic_pH1_0_ChemAxon_cxcalc_15_6_Max and reaction Reaction_133226
#   reaction_pH_descriptor_heading, reaction))
#
# /home/rich/DRP/DRP/plugins/rxndescriptors/drp.py:714: UserWarning: Could not find descriptor value for descriptor Solv_avgpol_pH1_0_ChemAxon_cxcalc_15_6_Range and reaction Reaction_133226
#   reaction_pH_descriptor_heading, reaction))
#
# /home/rich/DRP/DRP/plugins/rxndescriptors/drp.py:714: UserWarning: Could not find descriptor value for descriptor Solv_asa_polar_pH1_0_ChemAxon_cxcalc_15_6_Range and reaction Reaction_133226
#   reaction_pH_descriptor_heading, reaction))
#
# /home/rich/DRP/DRP/plugins/rxndescriptors/drp.py:714: UserWarning: Could not find descriptor value for descriptor Org_hbda_acc_pH1_0_ChemAxon_cxcalc_15_6_gmean_molarity and reaction Reaction_133226
#   reaction_pH_descriptor_heading, reaction))
#
# /home/rich/DRP/DRP/plugins/rxndescriptors/drp.py:714: UserWarning: Could not find descriptor value for descriptor Inorg_vanderwaals_pH1_0_ChemAxon_cxcalc_15_6_gmean_count and reaction Reaction_133226
#   reaction_pH_descriptor_heading, reaction))
#
# /home/rich/DRP/DRP/plugins/rxndescriptors/drp.py:714: UserWarning: Could not find descriptor value for descriptor Inorg_avgpol_pH1_0_ChemAxon_cxcalc_15_6_gmean_molarity and reaction Reaction_133226
#   reaction_pH_descriptor_heading, reaction))
#
# /home/rich/DRP/DRP/plugins/rxndescriptors/drp.py:714: UserWarning: Could not find descriptor value for descriptor Org_hbda_acc_pH1_0_ChemAxon_cxcalc_15_6_Max and reaction Reaction_133226
#   reaction_pH_descriptor_heading, reaction))
#
# /home/rich/DRP/DRP/plugins/rxndescriptors/drp.py:714: UserWarning: Could not find descriptor value for descriptor Solv_hbda_don_pH1_0_ChemAxon_cxcalc_15_6_gmean_molarity and reaction Reaction_133226
#   reaction_pH_descriptor_heading, reaction))
#
# /home/rich/DRP/DRP/plugins/rxndescriptors/drp.py:714: UserWarning: Could not find descriptor value for descriptor Org_asa_pH1_0_ChemAxon_cxcalc_15_6_Range and reaction Reaction_133226
#   reaction_pH_descriptor_heading, reaction))
#
# /home/rich/DRP/DRP/plugins/rxndescriptors/drp.py:714: UserWarning: Could not find descriptor value for descriptor Inorg_vanderwaals_pH1_0_ChemAxon_cxcalc_15_6_gmean_molarity and reaction Reaction_133226
#   reaction_pH_descriptor_heading, reaction))
#
# /home/rich/DRP/DRP/plugins/rxndescriptors/drp.py:714: UserWarning: Could not find descriptor value for descriptor Org_avgpol_pH1_0_ChemAxon_cxcalc_15_6_gmean_molarity and reaction Reaction_133226
#   reaction_pH_descriptor_heading, reaction))
#
# /home/rich/DRP/DRP/plugins/rxndescriptors/drp.py:714: UserWarning: Could not find descriptor value for descriptor Solv_asa+_pH1_0_ChemAxon_cxcalc_15_6_gmean_count and reaction Reaction_133226
#   reaction_pH_descriptor_heading, reaction))
#
# /home/rich/DRP/DRP/plugins/rxndescriptors/drp.py:714: UserWarning: Could not find descriptor value for descriptor Org_asa_hydrophobic_pH1_0_ChemAxon_cxcalc_15_6_Range and reaction Reaction_133226
#   reaction_pH_descriptor_heading, reaction))
#
# /home/rich/DRP/DRP/plugins/rxndescriptors/drp.py:714: UserWarning: Could not find descriptor value for descriptor Solv_asa+_pH1_0_ChemAxon_cxcalc_15_6_Range and reaction Reaction_133226
#   reaction_pH_descriptor_heading, reaction))
#
# /home/rich/DRP/DRP/plugins/rxndescriptors/drp.py:714: UserWarning: Could not find descriptor value for descriptor Inorg_hbda_acc_pH1_0_ChemAxon_cxcalc_15_6_Max and reaction Reaction_133226
#   reaction_pH_descriptor_heading, reaction))
#
# /home/rich/DRP/DRP/plugins/rxndescriptors/drp.py:714: UserWarning: Could not find descriptor value for descriptor Inorg_hbda_don_pH1_0_ChemAxon_cxcalc_15_6_Range and reaction Reaction_133226
#   reaction_pH_descriptor_heading, reaction))
#
# /home/rich/DRP/DRP/plugins/rxndescriptors/drp.py:714: UserWarning: Could not find descriptor value for descriptor Org_hbda_acc_pH1_0_ChemAxon_cxcalc_15_6_gmean_count and reaction Reaction_133226
#   reaction_pH_descriptor_heading, reaction))
#
# /home/rich/DRP/DRP/plugins/rxndescriptors/drp.py:714: UserWarning: Could not find descriptor value for descriptor Org_asa_pH1_0_ChemAxon_cxcalc_15_6_gmean_count and reaction Reaction_133226
#   reaction_pH_descriptor_heading, reaction))
#
# /home/rich/DRP/DRP/plugins/rxndescriptors/drp.py:714: UserWarning: Could not find descriptor value for descriptor Inorg_asa+_pH1_0_ChemAxon_cxcalc_15_6_gmean_count and reaction Reaction_133226
#   reaction_pH_descriptor_heading, reaction))
#
# /home/rich/DRP/DRP/plugins/rxndescriptors/drp.py:714: UserWarning: Could not find descriptor value for descriptor Org_asa-_pH1_0_ChemAxon_cxcalc_15_6_gmean_molarity and reaction Reaction_133226
#   reaction_pH_descriptor_heading, reaction))
#
# /home/rich/DRP/DRP/plugins/rxndescriptors/drp.py:714: UserWarning: Could not find descriptor value for descriptor Solv_asa+_pH1_0_ChemAxon_cxcalc_15_6_Max and reaction Reaction_133226
#   reaction_pH_descriptor_heading, reaction))
#
# /home/rich/DRP/DRP/plugins/rxndescriptors/drp.py:714: UserWarning: Could not find descriptor value for descriptor Solv_vanderwaals_pH1_0_ChemAxon_cxcalc_15_6_Max and reaction Reaction_133226
#   reaction_pH_descriptor_heading, reaction))
#
# /home/rich/DRP/DRP/plugins/rxndescriptors/drp.py:714: UserWarning: Could not find descriptor value for descriptor Org_vanderwaals_pH1_0_ChemAxon_cxcalc_15_6_Range and reaction Reaction_133226
#   reaction_pH_descriptor_heading, reaction))
#
# /home/rich/DRP/DRP/plugins/rxndescriptors/drp.py:714: UserWarning: Could not find descriptor value for descriptor Inorg_asa-_pH1_0_ChemAxon_cxcalc_15_6_Range and reaction Reaction_133226
#   reaction_pH_descriptor_heading, reaction))
#
# /home/rich/DRP/DRP/plugins/rxndescriptors/drp.py:714: UserWarning: Could not find descriptor value for descriptor Solv_asa-_pH1_0_ChemAxon_cxcalc_15_6_Range and reaction Reaction_133226
#   reaction_pH_descriptor_heading, reaction))
#
# /home/rich/DRP/DRP/plugins/rxndescriptors/drp.py:714: UserWarning: Could not find descriptor value for descriptor Inorg_asa-_pH1_0_ChemAxon_cxcalc_15_6_Max and reaction Reaction_133226
#   reaction_pH_descriptor_heading, reaction))
#
# /home/rich/DRP/DRP/plugins/rxndescriptors/drp.py:714: UserWarning: Could not find descriptor value for descriptor Inorg_asa_hydrophobic_pH1_0_ChemAxon_cxcalc_15_6_Max and reaction Reaction_133226
#   reaction_pH_descriptor_heading, reaction))
#
# /home/rich/DRP/DRP/plugins/rxndescriptors/drp.py:714: UserWarning: Could not find descriptor value for descriptor Solv_hbda_acc_pH1_0_ChemAxon_cxcalc_15_6_gmean_count and reaction Reaction_133226
#   reaction_pH_descriptor_heading, reaction))
#
# /home/rich/DRP/DRP/plugins/rxndescriptors/drp.py:714: UserWarning: Could not find descriptor value for descriptor Solv_molpol_pH1_0_ChemAxon_cxcalc_15_6_gmean_count and reaction Reaction_133226
#   reaction_pH_descriptor_heading, reaction))
#
# /home/rich/DRP/DRP/plugins/rxndescriptors/drp.py:714: UserWarning: Could not find descriptor value for descriptor Inorg_polar_surface_area_pH1_0_ChemAxon_cxcalc_16_5_Range and reaction Reaction_133226
#   reaction_pH_descriptor_heading, reaction))
#
# /home/rich/DRP/DRP/plugins/rxndescriptors/drp.py:714: UserWarning: Could not find descriptor value for descriptor Org_avgpol_pH1_0_ChemAxon_cxcalc_15_6_Range and reaction Reaction_133226
#   reaction_pH_descriptor_heading, reaction))
#
# /home/rich/DRP/DRP/plugins/rxndescriptors/drp.py:714: UserWarning: Could not find descriptor value for descriptor Solv_asa_hydrophobic_pH1_0_ChemAxon_cxcalc_15_6_Range and reaction Reaction_133226
#   reaction_pH_descriptor_heading, reaction))
#
# /home/rich/DRP/DRP/plugins/rxndescriptors/drp.py:714: UserWarning: Could not find descriptor value for descriptor Solv_vanderwaals_pH1_0_ChemAxon_cxcalc_15_6_Range and reaction Reaction_133226
#   reaction_pH_descriptor_heading, reaction))
#
# /home/rich/DRP/DRP/plugins/rxndescriptors/drp.py:714: UserWarning: Could not find descriptor value for descriptor Inorg_asa_hydrophobic_pH1_0_ChemAxon_cxcalc_15_6_gmean_count and reaction Reaction_133226
#   reaction_pH_descriptor_heading, reaction))
#
# /home/rich/DRP/DRP/plugins/rxndescriptors/drp.py:714: UserWarning: Could not find descriptor value for descriptor Solv_hbda_acc_pH1_0_ChemAxon_cxcalc_15_6_Range and reaction Reaction_133226
#   reaction_pH_descriptor_heading, reaction))
#
# /home/rich/DRP/DRP/plugins/rxndescriptors/drp.py:714: UserWarning: Could not find descriptor value for descriptor Solv_hbda_acc_pH1_0_ChemAxon_cxcalc_15_6_Max and reaction Reaction_133226
#   reaction_pH_descriptor_heading, reaction))
#
# /home/rich/DRP/DRP/plugins/rxndescriptors/drp.py:714: UserWarning: Could not find descriptor value for descriptor Org_asa+_pH1_0_ChemAxon_cxcalc_15_6_gmean_molarity and reaction Reaction_133226
#   reaction_pH_descriptor_heading, reaction))
#
# /home/rich/DRP/DRP/plugins/rxndescriptors/drp.py:714: UserWarning: Could not find descriptor value for descriptor Solv_asa_pH1_0_ChemAxon_cxcalc_15_6_gmean_molarity and reaction Reaction_133226
#   reaction_pH_descriptor_heading, reaction))
#
# /home/rich/DRP/DRP/plugins/rxndescriptors/drp.py:714: UserWarning: Could not find descriptor value for descriptor Solv_avgpol_pH1_0_ChemAxon_cxcalc_15_6_gmean_count and reaction Reaction_133226
#   reaction_pH_descriptor_heading, reaction))
#
# /home/rich/DRP/DRP/plugins/rxndescriptors/drp.py:714: UserWarning: Could not find descriptor value for descriptor Solv_vanderwaals_pH1_0_ChemAxon_cxcalc_15_6_gmean_count and reaction Reaction_133226
#   reaction_pH_descriptor_heading, reaction))
#
# /home/rich/DRP/DRP/plugins/rxndescriptors/drp.py:714: UserWarning: Could not find descriptor value for descriptor Solv_asa_pH1_0_ChemAxon_cxcalc_15_6_Range and reaction Reaction_133226
#   reaction_pH_descriptor_heading, reaction))
#
# /home/rich/DRP/DRP/plugins/rxndescriptors/drp.py:714: UserWarning: Could not find descriptor value for descriptor Org_hbda_don_pH1_0_ChemAxon_cxcalc_15_6_gmean_molarity and reaction Reaction_133226
#   reaction_pH_descriptor_heading, reaction))
#
# /home/rich/DRP/DRP/plugins/rxndescriptors/drp.py:714: UserWarning: Could not find descriptor value for descriptor Inorg_asa_polar_pH1_0_ChemAxon_cxcalc_15_6_Range and reaction Reaction_133226
#   reaction_pH_descriptor_heading, reaction))
#
# /home/rich/DRP/DRP/plugins/rxndescriptors/drp.py:714: UserWarning: Could not find descriptor value for descriptor Org_asa+_pH1_0_ChemAxon_cxcalc_15_6_Range and reaction Reaction_133226
#   reaction_pH_descriptor_heading, reaction))
#
# /home/rich/DRP/DRP/plugins/rxndescriptors/drp.py:714: UserWarning: Could not find descriptor value for descriptor Inorg_hbda_acc_pH1_0_ChemAxon_cxcalc_15_6_Range and reaction Reaction_133226
#   reaction_pH_descriptor_heading, reaction))
#
# /home/rich/DRP/DRP/plugins/rxndescriptors/drp.py:714: UserWarning: Could not find descriptor value for descriptor Inorg_molpol_pH1_0_ChemAxon_cxcalc_15_6_Max and reaction Reaction_133226
#   reaction_pH_descriptor_heading, reaction))
#
# /home/rich/DRP/DRP/plugins/rxndescriptors/drp.py:714: UserWarning: Could not find descriptor value for descriptor Solv_asa_hydrophobic_pH1_0_ChemAxon_cxcalc_15_6_gmean_molarity and reaction Reaction_133226
#   reaction_pH_descriptor_heading, reaction))
#
# /home/rich/DRP/DRP/plugins/rxndescriptors/drp.py:714: UserWarning: Could not find descriptor value for descriptor Inorg_polar_surface_area_pH1_0_ChemAxon_cxcalc_16_5_Max and reaction Reaction_133226
#   reaction_pH_descriptor_heading, reaction))
#
# /home/rich/DRP/DRP/plugins/rxndescriptors/drp.py:714: UserWarning: Could not find descriptor value for descriptor Org_molpol_pH1_0_ChemAxon_cxcalc_15_6_gmean_count and reaction Reaction_133226
#   reaction_pH_descriptor_heading, reaction))
#
# /home/rich/DRP/DRP/plugins/rxndescriptors/drp.py:714: UserWarning: Could not find descriptor value for descriptor Inorg_polar_surface_area_pH1_0_ChemAxon_cxcalc_16_5_gmean_molarity and reaction Reaction_133226
#   reaction_pH_descriptor_heading, reaction))
#
# /home/rich/DRP/DRP/plugins/rxndescriptors/drp.py:714: UserWarning: Could not find descriptor value for descriptor Solv_molpol_pH1_0_ChemAxon_cxcalc_15_6_gmean_molarity and reaction Reaction_133226
#   reaction_pH_descriptor_heading, reaction))
#
# /home/rich/DRP/DRP/plugins/rxndescriptors/drp.py:714: UserWarning: Could not find descriptor value for descriptor Org_molpol_pH1_0_ChemAxon_cxcalc_15_6_gmean_molarity and reaction Reaction_133226
#   reaction_pH_descriptor_heading, reaction))
#
# /home/rich/DRP/DRP/plugins/rxndescriptors/drp.py:714: UserWarning: Could not find descriptor value for descriptor Org_hbda_don_pH1_0_ChemAxon_cxcalc_15_6_Max and reaction Reaction_133226
#   reaction_pH_descriptor_heading, reaction))
#
# /home/rich/DRP/DRP/plugins/rxndescriptors/drp.py:714: UserWarning: Could not find descriptor value for descriptor Org_asa_pH1_0_ChemAxon_cxcalc_15_6_gmean_molarity and reaction Reaction_133226
#   reaction_pH_descriptor_heading, reaction))
#
# /home/rich/DRP/DRP/plugins/rxndescriptors/drp.py:714: UserWarning: Could not find descriptor value for descriptor Inorg_hbda_don_pH1_0_ChemAxon_cxcalc_15_6_Max and reaction Reaction_133226
#   reaction_pH_descriptor_heading, reaction))
#
# /home/rich/DRP/DRP/plugins/rxndescriptors/drp.py:714: UserWarning: Could not find descriptor value for descriptor Org_asa_polar_pH1_0_ChemAxon_cxcalc_15_6_Range and reaction Reaction_133226
#   reaction_pH_descriptor_heading, reaction))
#
# /home/rich/DRP/DRP/plugins/rxndescriptors/drp.py:714: UserWarning: Could not find descriptor value for descriptor Inorg_asa_pH1_0_ChemAxon_cxcalc_15_6_gmean_count and reaction Reaction_133226
#   reaction_pH_descriptor_heading, reaction))
#
# /home/rich/DRP/DRP/plugins/rxndescriptors/drp.py:714: UserWarning: Could not find descriptor value for descriptor Inorg_hbda_don_pH1_0_ChemAxon_cxcalc_15_6_gmean_molarity and reaction Reaction_133226
#   reaction_pH_descriptor_heading, reaction))
#
# /home/rich/DRP/DRP/plugins/rxndescriptors/drp.py:714: UserWarning: Could not find descriptor value for descriptor Org_molpol_pH1_0_ChemAxon_cxcalc_15_6_Range and reaction Reaction_133226
#   reaction_pH_descriptor_heading, reaction))
#
# /home/rich/DRP/DRP/plugins/rxndescriptors/drp.py:714: UserWarning: Could not find descriptor value for descriptor Solv_asa_hydrophobic_pH1_0_ChemAxon_cxcalc_15_6_Max and reaction Reaction_133226
#   reaction_pH_descriptor_heading, reaction))
#
# /home/rich/DRP/DRP/plugins/rxndescriptors/drp.py:714: UserWarning: Could not find descriptor value for descriptor Solv_asa_hydrophobic_pH1_0_ChemAxon_cxcalc_15_6_gmean_count and reaction Reaction_133226
#   reaction_pH_descriptor_heading, reaction))
#
# /home/rich/DRP/DRP/plugins/rxndescriptors/drp.py:714: UserWarning: Could not find descriptor value for descriptor Solv_asa-_pH1_0_ChemAxon_cxcalc_15_6_gmean_molarity and reaction Reaction_133226
#   reaction_pH_descriptor_heading, reaction))
#
# /home/rich/DRP/DRP/plugins/rxndescriptors/drp.py:714: UserWarning: Could not find descriptor value for descriptor Org_polar_surface_area_pH1_0_ChemAxon_cxcalc_16_5_gmean_count and reaction Reaction_133226
#   reaction_pH_descriptor_heading, reaction))
#
# /home/rich/DRP/DRP/plugins/rxndescriptors/drp.py:714: UserWarning: Could not find descriptor value for descriptor Org_hbda_acc_pH1_0_ChemAxon_cxcalc_15_6_Range and reaction Reaction_133226
#   reaction_pH_descriptor_heading, reaction))
#
# /home/rich/DRP/DRP/plugins/rxndescriptors/drp.py:714: UserWarning: Could not find descriptor value for descriptor Solv_polar_surface_area_pH1_0_ChemAxon_cxcalc_16_5_gmean_count and reaction Reaction_133226
#   reaction_pH_descriptor_heading, reaction))
#
# /home/rich/DRP/DRP/plugins/rxndescriptors/drp.py:714: UserWarning: Could not find descriptor value for descriptor Inorg_molpol_pH1_0_ChemAxon_cxcalc_15_6_gmean_molarity and reaction Reaction_133226
#   reaction_pH_descriptor_heading, reaction))
#
# /home/rich/DRP/DRP/plugins/rxndescriptors/drp.py:714: UserWarning: Could not find descriptor value for descriptor Org_polar_surface_area_pH1_0_ChemAxon_cxcalc_16_5_Range and reaction Reaction_133226
#   reaction_pH_descriptor_heading, reaction))
#
# /home/rich/DRP/DRP/plugins/rxndescriptors/drp.py:714: UserWarning: Could not find descriptor value for descriptor Org_asa+_pH1_0_ChemAxon_cxcalc_15_6_Max and reaction Reaction_133226
#   reaction_pH_descriptor_heading, reaction))
#
# /home/rich/DRP/DRP/plugins/rxndescriptors/drp.py:714: UserWarning: Could not find descriptor value for descriptor Inorg_asa_polar_pH1_0_ChemAxon_cxcalc_15_6_gmean_molarity and reaction Reaction_133226
#   reaction_pH_descriptor_heading, reaction))
#
# /home/rich/DRP/DRP/plugins/rxndescriptors/drp.py:714: UserWarning: Could not find descriptor value for descriptor Inorg
reaction Reaction_133226
#   reaction_pH_descriptor_heading, reaction))
#
# /home/rich/DRP/DRP/plugins/rxndescriptors/drp.py:714: UserWarning: Could not find descriptor value for descriptor Inorg_asa+_pH1_0_ChemAxon_cxcalc_15_6_gmean_molarity and reaction Reaction_133226
#   reaction_pH_descriptor_heading, reaction))
#
# /home/rich/DRP/DRP/plugins/rxndescriptors/drp.py:714: UserWarning: Could not find descriptor value for descriptor Org_asa_polar_pH1_0_ChemAxon_cxcalc_15_6_gmean_molarity and reaction Reaction_133226
#   reaction_pH_descriptor_heading, reaction))
#
# /home/rich/DRP/DRP/plugins/rxndescriptors/drp.py:714: UserWarning: Could not find descriptor value for descriptor Solv_polar_surface_area_pH1_0_ChemAxon_cxcalc_16_5_Range and reaction Reaction_133226
#   reaction_pH_descriptor_heading, reaction))
#
# /home/rich/DRP/DRP/plugins/rxndescriptors/drp.py:714: UserWarning: Could not find descriptor value for descriptor Inorg_molpol_pH1_0_ChemAxon_cxcalc_15_6_Range and reaction Reaction_133226
#   reaction_pH_descriptor_heading, reaction))
#
# /home/rich/DRP/DRP/plugins/rxndescriptors/drp.py:714: UserWarning: Could not find descriptor value for descriptor Solv_asa_pH1_0_ChemAxon_cxcalc_15_6_gmean_count and reaction Reaction_133226
#   reaction_pH_descriptor_heading, reaction))
#
# /home/rich/DRP/DRP/plugins/rxndescriptors/drp.py:714: UserWarning: Could not find descriptor value for descriptor Inorg_asa_hydrophobic_pH1_0_ChemAxon_cxcalc_15_6_gmean_molarity and reaction Reaction_133226
#   reaction_pH_descriptor_heading, reaction))
#
# /home/rich/DRP/DRP/plugins/rxndescriptors/drp.py:714: UserWarning: Could not find descriptor value for descriptor Inorg_asa+_pH1_0_ChemAxon_cxcalc_15_6_Max and reaction Reaction_133226
#   reaction_pH_descriptor_heading, reaction))
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-3-9266b947a429> in <module>()
# ----> 1 recommendations = rec.recommend()
#
# /home/rich/DRP/DRP/recommender/ReactionRecommender.pyc in recommend(self)
#     174         count = 0
#     175         plausible_reaction_ids = []
# --> 176         for i in self.plausible_reactions:
#     177             plausible_reaction_ids.append(i.pk)
#     178             if count > 1000:
#
# /home/rich/DRP/DRP/recommender/ReactionGenerator.pyc in generate(self, compound_triples)
#     126                         compound_quantity.save()
#     127
# --> 128                     new_rxn.save(calcDescriptors=True)
#     129
#     130                     # Calculate reaction hash for the proposed reaction
#
# /home/rich/DRP/DRP/models/Reaction.pyc in save(self, calcDescriptors, *args, **kwargs)
#     242         if calcDescriptors and self.calcDescriptors:
#     243             for plugin in descriptorPlugins:
# --> 244                 plugin.calculate(self)
#     245
#     246     @property
#
# /home/rich/DRP/DRP/plugins/rxndescriptors/drp.py in calculate(reaction, verbose, whitelist)
#     435     if verbose:
#     436         print "Creating {} Numeric values".format(len(num_vals_to_create))
# --> 437     DRP.models.NumRxnDescriptorValue.objects.bulk_create(num_vals_to_create)
#     438
#     439
#
# /usr/local/lib/python2.7/dist-packages/django/db/models/manager.pyc in manager_method(self, *args, **kwargs)
#     125         def create_method(name, method):
#     126             def manager_method(self, *args, **kwargs):
# --> 127                 return getattr(self.get_queryset(), name)(*args, **kwargs)
#     128             manager_method.__name__ = method.__name__
#     129             manager_method.__doc__ = method.__doc__
#
# /usr/local/lib/python2.7/dist-packages/django/db/models/query.pyc in bulk_create(self, objs, batch_size)
#     390                 if objs_without_pk:
#     391                     fields = [f for f in fields if not isinstance(f, AutoField)]
# --> 392                     self._batched_insert(objs_without_pk, fields, batch_size)
#     393
#     394         return objs
#
# /usr/local/lib/python2.7/dist-packages/django/db/models/query.pyc in _batched_insert(self, objs, fields, batch_size)
#     935                       for i in range(0, len(objs), batch_size)]:
#     936             self.model._base_manager._insert(batch, fields=fields,
# --> 937                                              using=self.db)
#     938
#     939     def _clone(self, klass=None, setup=False, **kwargs):
#
# /usr/local/lib/python2.7/dist-packages/django/db/models/manager.pyc in manager_method(self, *args, **kwargs)
#     125         def create_method(name, method):
#     126             def manager_method(self, *args, **kwargs):
# --> 127                 return getattr(self.get_queryset(), name)(*args, **kwargs)
#     128             manager_method.__name__ = method.__name__
#     129             manager_method.__doc__ = method.__doc__
#
# /usr/local/lib/python2.7/dist-packages/django/db/models/query.pyc in _insert(self, objs, fields, return_id, raw, using)
#     918         query = sql.InsertQuery(self.model)
#     919         query.insert_values(fields, objs, raw=raw)
# --> 920         return query.get_compiler(using=using).execute_sql(return_id)
#     921     _insert.alters_data = True
#     922     _insert.queryset_only = False
#
# /usr/local/lib/python2.7/dist-packages/django/db/models/sql/compiler.pyc in execute_sql(self, return_id)
#     961         with self.connection.cursor() as cursor:
#     962             for sql, params in self.as_sql():
# --> 963                 cursor.execute(sql, params)
#     964             if not (return_id and cursor):
#     965                 return
#
# /usr/local/lib/python2.7/dist-packages/django/db/backends/utils.pyc in execute(self, sql, params)
#      77         start = time()
#      78         try:
# ---> 79             return super(CursorDebugWrapper, self).execute(sql, params)
#      80         finally:
#      81             stop = time()
#
# /usr/local/lib/python2.7/dist-packages/django/db/backends/utils.pyc in execute(self, sql, params)
#      62                 return self.cursor.execute(sql)
#      63             else:
# ---> 64                 return self.cursor.execute(sql, params)
#      65
#      66     def executemany(self, sql, param_list):
#
# /usr/local/lib/python2.7/dist-packages/django/db/utils.pyc in __exit__(self, exc_type, exc_value, traceback)
#      95                 if dj_exc_type not in (DataError, IntegrityError):
#      96                     self.wrapper.errors_occurred = True
# ---> 97                 six.reraise(dj_exc_type, dj_exc_value, traceback)
#      98
#      99     def __call__(self, func):
#
# /usr/local/lib/python2.7/dist-packages/django/db/backends/utils.pyc in execute(self, sql, params)
#      62                 return self.cursor.execute(sql)
#      63             else:
# ---> 64                 return self.cursor.execute(sql, params)
#      65
#      66     def executemany(self, sql, param_list):
#
# /usr/local/lib/python2.7/dist-packages/django/db/backends/mysql/base.pyc in execute(self, query, args)
#     122         try:
#     123             # args is None means no string interpolation
# --> 124             return self.cursor.execute(query, args)
#     125         except Database.OperationalError as e:
#     126             # Map some error codes to IntegrityError, since they seem to be
#
# /usr/local/lib/python2.7/dist-packages/MySQLdb/cursors.pyc in execute(self, query, args)
#     203             del tb
#     204             self.messages.append((exc, value))
# --> 205             self.errorhandler(self, exc, value)
#     206         self._executed = query
#     207         if not self._defer_warnings: self._warning_check()
#
# /usr/local/lib/python2.7/dist-packages/MySQLdb/connections.pyc in defaulterrorhandler(***failed resolving arguments***)
#      34     del cursor
#      35     del connection
# ---> 36     raise errorclass, errorvalue
#      37
#      38 re_numeric_part = re.compile(r"^(\d+)")
#
# IntegrityError: (1062, "Duplicate entry '133226-10184' for key 'DRP_numrxndescriptorvalue_reaction_id_18226d434f3f78c2_uniq'")

# %%
recommendations

# %%
rec.lshash

# %%
# {'labGroup': <LabGroup: Norquist Lab>, u'boolean_crystallisation_outcome_prediction_1_component_2__': True, 'notes': u'Part of a grid search', u'reaction_temperature_manual_0': 363.15, u'boolean_crystallisation_outcome_prediction_1_component_4__': True, 'compound_1': u'Pyrimidin-2,4,6-triamin', u'boolean_crystallisation_outcome_prediction_1_summative__': True, u'reaction_time_manual_0': 1440.0, u'reaction_pH_manual_0': 1.0, u'boolean_crystallisation_outcome_prediction_1_component_3__': True, u'boolean_crystallisation_outcome_prediction_1_component_1__': True, u'rxnSpaceHash1_DRP_xxhash_0_02_0.5.0': <CategoricalDescriptorPermittedValue: 6d7655d389bf5bb6>, u'id': 132873L, 'compound_2': u'N,N,N\u2032,N\u2032-Tetramethyl-1,3-propanediamine', 'compound_0': u'Disodium tellurite'}

# %%
reaction_temperature_manual_0, reaction_time_manual_0, reaction_pH_manual_0,

# %%
a = rec.generator.generate(rec.a)

# %%
a.next()
