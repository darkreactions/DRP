# %%
from DRP.models import NumRxnDescriptor

# %%
for i in NumRxnDescriptor.objects.all():
    print i.pk, i
# Out:
# 4 Reaction temperature in degrees C
# 5 Reaction time in minutes
# 6 Reaction pH
# 7 Pre heat standing time
# 9 Mols of K in a reaction.
# 10 Mols of Yb in a reaction.
# 11 Mols of As in a reaction.
# 12 Mols of Xe in a reaction.
# 13 Mols of Ar in a reaction.
# 14 Mols of Hg in a reaction.
# 15 Mols of Co in a reaction.
# 16 Mols of Pb in a reaction.
# 17 Mols of Si in a reaction.
# 18 Mols of Rb in a reaction.
# 19 Mols of Ba in a reaction.
# 20 Mols of Na in a reaction.
# 21 Mols of Po in a reaction.
# 22 Mols of F in a reaction.
# 23 Mols of Ir in a reaction.
# 24 Mols of Eu in a reaction.
# 25 Mols of Sn in a reaction.
# 26 Mols of Os in a reaction.
# 27 Mols of O in a reaction.
# 28 Mols of Cl in a reaction.
# 29 Mols of Au in a reaction.
# 30 Mols of Mo in a reaction.
# 31 Mols of He in a reaction.
# 32 Mols of Ni in a reaction.
# 33 Mols of Mn in a reaction.
# 34 Mols of Ho in a reaction.
# 35 Mols of Cu in a reaction.
# 36 Mols of Sm in a reaction.
# ...

# %%
from DRP.models import NumRxnDescriptorValue

# %%
for i in NumRxnDescriptorValue.objects.all().reverse():
    print i
# Out:
# NumRxnDescriptorValue object
# NumRxnDescriptorValue object
# NumRxnDescriptorValue object
# NumRxnDescriptorValue object
# NumRxnDescriptorValue object
# NumRxnDescriptorValue object
# NumRxnDescriptorValue object
# NumRxnDescriptorValue object
# NumRxnDescriptorValue object
# NumRxnDescriptorValue object
# NumRxnDescriptorValue object
# NumRxnDescriptorValue object
# NumRxnDescriptorValue object
# NumRxnDescriptorValue object
# NumRxnDescriptorValue object
# NumRxnDescriptorValue object
# NumRxnDescriptorValue object
# NumRxnDescriptorValue object
# NumRxnDescriptorValue object
# NumRxnDescriptorValue object
# NumRxnDescriptorValue object
# NumRxnDescriptorValue object
# NumRxnDescriptorValue object
# NumRxnDescriptorValue object
# NumRxnDescriptorValue object
# NumRxnDescriptorValue object
# NumRxnDescriptorValue object
# NumRxnDescriptorValue object
# NumRxnDescriptorValue object
# NumRxnDescriptorValue object
# NumRxnDescriptorValue object
# NumRxnDescriptorValue object
# ...
